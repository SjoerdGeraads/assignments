# %% [markdown]
# # Exam R
# SjoerdGeraads, 2008618, u461243 /
# Mateo Malbasic,2009362
# , u826099
# # Introduction
#
# The exam consists of 2 parts. In the first part, you have to run a regression, test if the assumptions of a linear regression model are met, and make 2 graphs.
#
# In the second part of the exam, you will have to make a map of Catholic and Protestant schools in the Netherlands.
#
# # Packages

# %%
library(tidyverse)
library(gvlma)

# %% [markdown]
# # Assignment 1
#
#
# ## Data
#
# The data are given:

# %%
set.seed(123)
df1 <- as.data.frame(matrix(runif(1*50, min = 1, max = 10), ncol = 1)) %>%
    mutate(epsilon = rnorm(50, mean = 0, sd = 2)) %>%
    mutate(response = 3 - 2* V1  + epsilon) %>%
    mutate(group = ifelse(V1 <= 5, 1,2))

# %% [markdown]
# ## Asignment 1a
#
# The first assigment is to make boxplot using ggplot with group on the x-axis and V1 on the y-axis.

# %%
#We made a boxplot by using V1 on the y-axis and the group on the x-axis
ggplot(df1, aes(group=group ,x=group, y=V1)) + 
    geom_boxplot(fill = 'Red')
# Out:
# plot without title

# %% [markdown]
# ## Assignment 1b
#
# Run a regression with response variable as a function of V1.
# Show the summary statistics of the regression.

# %%
reg1 <- lm(data=df1, response ~ V1)
summary(reg1)
# Out:
# Call:
# lm(formula = response ~ V1, data = df1)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -4.5116 -1.1157 -0.1313  1.0985  4.3723
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   2.6305     0.6347   4.145 0.000138 ***
# V1           -1.9152     0.1014 -18.880  < 2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 1.881 on 48 degrees of freedom
# Multiple R-squared:  0.8813,	Adjusted R-squared:  0.8788
# F-statistic: 356.4 on 1 and 48 DF,  p-value: < 2.2e-16

# %% [markdown]
# check if the assumptions of linear regression are met with the `gvlma()` function.

# %%
gvlma(reg1)
# Out:
# Call:
# lm(formula = response ~ V1, data = df1)
#
# Coefficients:
# (Intercept)           V1
#       2.630       -1.915
#
#
# ASSESSMENT OF THE LINEAR MODEL ASSUMPTIONS
# USING THE GLOBAL TEST ON 4 DEGREES-OF-FREEDOM:
# Level of Significance =  0.05
#
# Call:
#  gvlma(x = reg1)
#
#                       Value p-value                Decision
# Global Stat        0.654319  0.9568 Assumptions acceptable.
# Skewness           0.002398  0.9609 Assumptions acceptable.
# Kurtosis           0.007200  0.9324 Assumptions acceptable.
# Link Function      0.005852  0.9390 Assumptions acceptable.
# Heteroscedasticity 0.638869  0.4241 Assumptions acceptable.

# %% [markdown]
# ## Assignment 1c
#
# Make a scatterplot with:
# * V1 on the x-axis and the response on the y-axis
# * Include the regression line in red with confidence interval
# * In a classic theme
# * The x-axis should be labeled "Predictor", the y-axis should be labeled ("Response")

# %%
#We plotted the regression line, which is the downward sloping red line. We did this by using the Response for the y-axis and the Predictor for the x-axis
plot(x=df1$V1, y=df1$response,col= 'Blue', xlab= 'Predictor', ylab='Response') + abline(lm(response~ V1, data = df1), col='Red')
# Out:
# numeric(0)
# plot without title

# %% [markdown]
# # Assigment 2
#
# # Packages

# %%
library(thematicmaps)
library(tidyverse)

# %% [markdown]
# ## Assignment 2a
#
# First you have to read in the file "nld_municipal_map.csv".
# Hint: Look at the notebook of week 6 about maps.

# %%
#We uploded the nld_municipal map to get a table of different variables
map_municipal <- read.csv2('nld_municipal_map.csv', stringsAsFactors = FALSE, dec = '.')
head(map_municipal)
# Out:
#   name       id x        y        order hole  piece group
# 1 Appingedam 0  251260.5 594393.8 1     FALSE 1     0.1
# 2 Appingedam 0  251427.8 594486.7 2     FALSE 1     0.1
# 3 Appingedam 0  251668.8 594646.8 3     FALSE 1     0.1
# 4 Appingedam 0  251713.5 594770.9 4     FALSE 1     0.1
# 5 Appingedam 0  251354.6 595461.4 5     FALSE 1     0.1
# 6 Appingedam 0  251310.3 596022.5 6     FALSE 1     0.1

# %% [markdown]
# ## Assignment 2b
#
# Now you can make an empty map of the Netherlands.

# %%
#we need to use Map plot to make a map of the Netherlands
AddMapLayer(MapPlot(), map_municipal)
# Out:
# plot without title

# %% [markdown]
# ## Assignment 2c
#
# Read in the pc4 locations (nld_pc4_locations.csv).
#
# Hint: Don't forget the X and Y should be numeric variables!

# %%
#We got the X and Y as numerical variables for the pc4 locations
pc4_locations <- read.csv2('nld_pc4_locations.csv', stringsAsFactors = FALSE, dec = '.') 

head(pc4_locations)
# Out:
#   PC4  X        Y
# 1 1011 122244.1 487223.1
# 2 1012 121612.8 487555.4
# 3 1013 120324.5 489671.7
# 4 1014 119515.0 489421.7
# 5 1015 120740.5 488009.3
# 6 1016 120537.8 487075.4

# %% [markdown]
# ## Assignment 2d
#
# ### 2di
#
# Read in the school data

# %%
#we needed to upload the schools file such that we could read this and get information such as the "Postcode"
schools <- read.csv2('schools.csv')
head(schools)
# Out:
#   PROVINCIE            BEVOEGD.GEZAG.NUMMER BRIN.NUMMER VESTIGINGSNUMMER
# 1                      41152                23HC        23HC04
# 2 Drenthe              10053                18BR        18BR00
# 3 Drenthe              10053                18BR        18BR01
# 4 Drenthe              13273                20LO        20LO00
# 5 Drenthe              13273                20LO        20LO01
# 6 Drenthe              13273                20LO        20LO02
#   VESTIGINGSNAAM
# 1 RSG Lingecollege
# 2 School voor Praktijkonderwijs Assen
# 3 School voor Praktijkonderwijs Assen
# 4 Openbare Scholengemeenschap Dr Nassau College voor Vwo Havo Mavo Vbo Lwoo
# 5 Openbare Scholengemeenschap Dr Nassau College voor Vwo Havo Mavo Vbo Lwoo
# 6 Openbare Scholengemeenschap Dr Nassau College voor Vwo Havo Mavo Vbo Lwoo
#   STRAATNAAM               HUISNUMMER.TOEVOEGING POSTCODE
# 1
# 2 Zwartwatersweg           202                   9406 NN
# 3 Bosrand                  2                     9401 SL
# 4 Mr Groen v Prinstererln  98                    9402 KG
# 5 Schoolstraat             1                     9331 AV
# 6 Esdoornlaan              2                     9411 AV
#   PLAATSNAAM               GEMEENTENUMMER ... RPA.GEBIED.CODE
# 1                            NA           ... NA
# 2 ASSEN                     106           ...  3
# 3 ASSEN                     106           ...  3
# 4 ASSEN                     106           ...  3
# 5 NORG                     1699           ...  3
# 6 BEILEN                   1731           ...  5
#   RPA.GEBIED.NAAM          WGR.GEBIED.CODE
# 1                          NA
# 2 Centraal-Groningen        7
# 3 Centraal-Groningen        7
# 4 Centraal-Groningen        7
# 5 Centraal-Groningen        7
# 6 Zuid- en Midden-Drenthe   7
#   WGR.GEBIED.NAAM                         COROPGEBIED.CODE
# 1                                         NA
# 2 Noord- en Midden-Drenthe                 7
# 3 Noord- en Midden-Drenthe                 7
# 4 Noord- en Midden-Drenthe                 7
# 5 Noord- en Midden-Drenthe                 7
# 6 Noord- en Midden-Drenthe                 7
#   COROPGEBIED.NAAM                    ONDERWIJSGEBIED.CODE
# 1                                     NA
# 2 Noord-Drenthe                        4
# 3 Noord-Drenthe                        4
# 4 Noord-Drenthe                        4
# 5 Noord-Drenthe                        1
# 6 Noord-Drenthe                        4
#   ONDERWIJSGEBIED.NAAM             RMC.REGIO.CODE
# 1                                  NA
# 2 Assen-Hoogeveen-Emmen             7
# 3 Assen-Hoogeveen-Emmen             7
# 4 Assen-Hoogeveen-Emmen             7
# 5 Groningen en omstreken            7
# 6 Assen-Hoogeveen-Emmen             7
#   RMC.REGIO.NAAM
# 1
# 2 Noord- en Midden Drenthe
# 3 Noord- en Midden Drenthe
# 4 Noord- en Midden Drenthe
# 5 Noord- en Midden Drenthe
# 6 Noord- en Midden Drenthe

# %% [markdown]
# ### 2dii
#
# First, create a new dataframe schools1, which is equal to schools.
#
# As you see POSTCODE has a structure of (1234 AB). You should create a new variable PC4 that is equal to the first 4 numbers in POSTCODE
#
# Hint: Use the function `substr()`
#
# Then select the variables PC4 and DENOMINATIE

# %%
#We need to select the PC4 and see which Denominatie it has, we did this by using the folowing:
schools1 <- schools %>% mutate(PC4=as.numeric(substr(POSTCODE,1,4))) %>% 
select (PC4, DENOMINATIE)
schools1
# Out:
#      PC4  DENOMINATIE
# 1      NA Openbaar
# 2    9406 Openbaar
# 3    9401 Openbaar
# 4    9402 Openbaar
# 5    9331 Openbaar
# 6    9411 Openbaar
# 7    9461 Openbaar
# 8    9402 Openbaar
# 9    9402 Openbaar
# 10   9403 Openbaar
# 11   9406 Openbaar
# 12   7905 Openbaar
# 13   7905 Openbaar
# 14   7905 Openbaar
# 15   7905 Openbaar
# 16   7905 Openbaar
# 17   9404 Algemeen bijzonder
# 18   9761 Algemeen bijzonder
# 19   7812 Algemeen bijzonder
# 20   7944 Algemeen bijzonder
# 21   7944 Algemeen bijzonder
# 22   7824 Rooms-Katholiek
# 23   9301 Algemeen bijzonder
# 24   9301 Algemeen bijzonder
# 25   7902 Protestants-Christelijk
# 26   7903 Protestants-Christelijk
# 27   7822 Protestants-Christelijk
# 28   7825 Algemeen bijzonder
# 29   7943 Openbaar
# 30   7943 Openbaar
# ...  ...  ...
# 1574 2231 Protestants-Christelijk
# 1575 2313 Rooms-Katholiek
# 1576 2371 Rooms-Katholiek
# 1577 2334 Rooms-Katholiek
# 1578 2334 Rooms-Katholiek
# 1579 4205 Protestants-Christelijk
# 1580 3371 Protestants-Christelijk
# 1581 4205 Protestants-Christelijk
# 1582 4204 Protestants-Christelijk
# 1583 4205 Protestants-Christelijk
# 1584 4207 Protestants-Christelijk
# 1585 4143 Protestants-Christelijk
# 1586 4142 Protestants-Christelijk
# 1587 3032 Algemeen bijzonder
# 1588 3039 Algemeen bijzonder
# 1589 2517 Protestants-Christelijk
# 1590 2551 Protestants-Christelijk
# 1591 3362 Samenwerking PC, Alg. Bijz.
# 1592 2241 Rooms-Katholiek
# 1593 3055 Rooms-Katholiek
# 1594 2401 Rooms-Katholiek
# 1595 2421 Rooms-Katholiek
# 1596 2585 Algemeen bijzonder
# 1597 2725 Rooms-Katholiek
# 1598 2614 Protestants-Christelijk
# 1599 2625 Protestants-Christelijk
# 1600 2625 Protestants-Christelijk
# 1601 2597 Antroposofisch
# 1602 3034 Antroposofisch
# 1603 2315 Antroposofisch

# %% [markdown]
# ### 2diii
#
# Create the dataframe school_loc as a join from pc4_locations and school1 that combines the columns from both data frames, but only keeps rows where the value in the pc4_locations column matches in both data frames.
# And then select the observations with DENOMINATIE is equal to "Rooms-Katholiek" or "Protestants-Christelijk"

# %%
school_loc <- merge(pc4_locations,schools1, by = 'PC4')
schools2 = filter(school_loc,DENOMINATIE %in% c('Rooms-Katholiek','Protestants-Christelijk'))
schools2
# Out:
#     PC4  X        Y        DENOMINATIE
# 1   1065 116701.2 485645.8 Protestants-Christelijk
# 2   1071 120223.0 485571.3 Rooms-Katholiek
# 3   1077 120152.7 484262.8 Protestants-Christelijk
# 4   1077 120152.7 484262.8 Rooms-Katholiek
# 5   1081 118277.6 482449.5 Protestants-Christelijk
# 6   1132 132947.2 501873.0 Rooms-Katholiek
# 7   1132 132947.2 501873.0 Rooms-Katholiek
# 8   1185 118214.4 478212.6 Protestants-Christelijk
# 9   1185 118214.4 478212.6 Rooms-Katholiek
# 10  1211 140459.1 470645.8 Rooms-Katholiek
# 11  1211 140459.1 470645.8 Rooms-Katholiek
# 12  1212 141853.7 469786.9 Rooms-Katholiek
# 13  1212 141853.7 469786.9 Rooms-Katholiek
# 14  1212 141853.7 469786.9 Rooms-Katholiek
# 15  1213 140219.8 468394.2 Rooms-Katholiek
# 16  1213 140219.8 468394.2 Rooms-Katholiek
# 17  1215 139155.7 469643.8 Protestants-Christelijk
# 18  1217 139160.4 472396.9 Protestants-Christelijk
# 19  1221 141339.2 471170.3 Protestants-Christelijk
# 20  1222 141304.2 473261.7 Protestants-Christelijk
# 21  1222 141304.2 473261.7 Protestants-Christelijk
# 22  1251 143664.4 473568.1 Rooms-Katholiek
# 23  1276 145546.3 478382.0 Protestants-Christelijk
# 24  1405 138900.5 476578.4 Protestants-Christelijk
# 25  1421 116936.6 472385.7 Rooms-Katholiek
# 26  1422 116696.6 473235.9 Rooms-Katholiek
# 27  1509 117003.0 498312.2 Rooms-Katholiek
# 28  1624 132663.5 517704.3 Rooms-Katholiek
# 29  1624 132663.5 517704.3 Rooms-Katholiek
# 30  1625 132495.5 518777.0 Rooms-Katholiek
# ... ...  ...      ...      ...
# 567 9076 173448.7 588242.5 Protestants-Christelijk
# 568 9076 173448.7 588242.5 Protestants-Christelijk
# 569 9101 195835.9 593130.2 Protestants-Christelijk
# 570 9101 195835.9 593130.2 Protestants-Christelijk
# 571 9101 195835.9 593130.2 Protestants-Christelijk
# 572 9101 195835.9 593130.2 Protestants-Christelijk
# 573 9103 196183.5 592470.5 Protestants-Christelijk
# 574 9104 194640.6 590252.6 Protestants-Christelijk
# 575 9172 184459.3 594818.4 Protestants-Christelijk
# 576 9202 203882.2 569555.7 Protestants-Christelijk
# 577 9202 203882.2 569555.7 Protestants-Christelijk
# 578 9202 203882.2 569555.7 Protestants-Christelijk
# 579 9251 195282.1 579590.0 Protestants-Christelijk
# 580 9251 195282.1 579590.0 Protestants-Christelijk
# 581 9285 207145.2 585459.1 Protestants-Christelijk
# 582 9291 206346.7 589139.4 Protestants-Christelijk
# 583 9404 235762.2 556213.9 Protestants-Christelijk
# 584 9405 231985.5 554609.9 Protestants-Christelijk
# 585 9406 231892.2 557973.9 Protestants-Christelijk
# 586 9411 230301.1 541915.0 Protestants-Christelijk
# 587 9422 226773.0 551209.3 Protestants-Christelijk
# 588 9602 245531.1 574965.0 Protestants-Christelijk
# 589 9721 234211.4 579338.4 Protestants-Christelijk
# 590 9726 233050.3 581265.1 Protestants-Christelijk
# 591 9727 232434.5 580220.7 Protestants-Christelijk
# 592 9731 235326.5 583736.0 Protestants-Christelijk
# 593 9732 237198.0 583814.4 Protestants-Christelijk
# 594 9743 231395.2 582385.8 Protestants-Christelijk
# 595 9843 216302.4 587537.5 Protestants-Christelijk
# 596 9951 229654.2 594755.2 Protestants-Christelijk

# %% [markdown]
# ## Assignment 2e
#
# Create a map of Catholic and Protestant schools in the Netherlands

# %%
#We need to create a map of the Netherlands and using dots to see where the Catholic an Protestant schools are in the Netherlands, so we add: AddPointsLayer
AddMapLayer(MapPlot(), map_municipal) %>%
AddPointsLayer(schools2)
# Out:
# plot without title

# %% [markdown]
# End of notebook
